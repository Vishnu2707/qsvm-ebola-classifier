# %% [markdown]
# # QSVM Haemorrhagic Fever Classifier Analysis
#
# Run `python ../main.py` from the project root to generate metrics and figures, then use this notebook for exploratory inspection.

# %%
from pathlib import Path
import json
import pandas as pd

root = Path('..')
dataset_path = root / 'results' / 'dataset.csv'
if dataset_path.exists():
    df = pd.read_csv(dataset_path)
    display(df.head())
    display(df['label'].value_counts())
else:
    print('Run the pipeline first: python main.py --skip-pdf --skip-qsvm')
